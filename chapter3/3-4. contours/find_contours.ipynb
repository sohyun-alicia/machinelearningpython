# %%
import cv2
import matplotlib.pyplot as plt

# %%
# !pip install clodsa==1.2.27
# Out:
# Collecting clodsa==1.2.27
#   Downloading clodsa-1.2.27.tar.gz (28 kB)
# Collecting mahotas
#   Downloading mahotas-1.4.11-cp37-cp37m-win_amd64.whl (1.7 MB)
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
# Requirement already satisfied: Keras in c:\users\82108\anaconda3\lib\site-packages (from clodsa==1.2.27) (2.1.4)
# Collecting commentjson
#   Downloading commentjson-0.9.0.tar.gz (8.7 kB)
# Requirement already satisfied: scipy in c:\users\82108\anaconda3\lib\site-packages (from clodsa==1.2.27) (1.4.1)
# Requirement already satisfied: h5py in c:\users\82108\anaconda3\lib\site-packages (from clodsa==1.2.27) (3.1.0)
# Requirement already satisfied: numpy in c:\users\82108\anaconda3\lib\site-packages (from clodsa==1.2.27) (1.19.5)
# Collecting progressbar2
#   Downloading progressbar2-3.53.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: scikit_learn in c:\users\82108\anaconda3\lib\site-packages (from clodsa==1.2.27) (0.22.1)
# Collecting lark-parser<0.8.0,>=0.7.1
#   Downloading lark-parser-0.7.8.tar.gz (276 kB)
# Requirement already satisfied: cached-property in c:\users\82108\anaconda3\lib\site-packages (from h5py->clodsa==1.2.27) (1.5.2)
# Requirement already satisfied: pyyaml in c:\users\82108\anaconda3\lib\site-packages (from Keras->clodsa==1.2.27) (5.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\82108\appdata\roaming\python\python37\site-packages (from Keras->clodsa==1.2.27) (1.15.0)
# Collecting python-utils>=2.3.0
#   Downloading python_utils-2.5.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: joblib>=0.11 in c:\users\82108\anaconda3\lib\site-packages (from scikit_learn->clodsa==1.2.27) (0.14.1)
# WARNING: Ignoring invalid distribution -umpy (c:\users\82108\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\82108\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\82108\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\82108\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\82108\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\82108\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\82108\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\82108\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\82108\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\82108\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\82108\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\82108\anaconda3\lib\site-packages)
# Building wheels for collected packages: clodsa, commentjson, lark-parser, imutils
#   Building wheel for clodsa (setup.py): started
#   Building wheel for clodsa (setup.py): finished with status 'done'
#   Created wheel for clodsa: filename=clodsa-1.2.27-py2.py3-none-any.whl size=70291 sha256=04ed8d33caf4577a623f96028af4ed085f05598a88d9bf3a9a4a0fa5357b7721
#   Stored in directory: c:\users\82108\appdata\local\pip\cache\wheels\6b\ad\b6\c8eae274c697edd641a83deabf5850184054381f82ae92510a
#   Building wheel for commentjson (setup.py): started
#   Building wheel for commentjson (setup.py): finished with status 'done'
#   Created wheel for commentjson: filename=commentjson-0.9.0-py3-none-any.whl size=12083 sha256=913015cba45023a148e102c9579ae0684c2e08e348de4d7590a76d9172ca0b86
#   Stored in directory: c:\users\82108\appdata\local\pip\cache\wheels\eb\bb\07\25a7f0718ee3fe137384011b8e56070f91cf950ee6047c287f
#   Building wheel for lark-parser (setup.py): started
#   Building wheel for lark-parser (setup.py): finished with status 'done'
#   Created wheel for lark-parser: filename=lark_parser-0.7.8-py2.py3-none-any.whl size=62514 sha256=393f4ffbc7a856bb96c43221a7b2754ea92382f51400fbe9160084bd89bb2895
#   Stored in directory: c:\users\82108\appdata\local\pip\cache\wheels\92\e3\af\1dc0fdca93232d700ac176af6554cf22b85f3d7e8aeee5ac08
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25860 sha256=d40fc9583baf67f8488822425a04432bd338d9543368acda494ffd1314df974d
#   Stored in directory: c:\users\82108\appdata\local\pip\cache\wheels\86\d7\0a\4923351ed1cec5d5e24c1eaf8905567b02a0343b24aa873df2
# Successfully built clodsa commentjson lark-parser imutils
# Installing collected packages: python-utils, lark-parser, progressbar2, mahotas, imutils, commentjson, clodsa
# Successfully installed clodsa-1.2.27 commentjson-0.9.0 imutils-0.5.4 lark-parser-0.7.8 mahotas-1.4.11 progressbar2-3.53.1 python-utils-2.5.6

# %%
# 이미지 읽어 들이고 크기 변경하기
img = cv2.imread("flower.jpg")
img = cv2.resize(img, (300, 169))

# 색공간 변경하기
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.GaussianBlur(gray, (7, 7), 0)
im2 = cv2.threshold(gray, 140, 240, cv2.THRESH_BINARY_INV)[1]

# 화면 왼쪽에 변환한 이미지 출력하기
plt.subplot(1, 2, 1)
plt.imshow(im2, cmap="gray")

# 윤곽 검출하기
cnts = cv2.findContours(im2,
                        cv2.RETR_LIST,
                        cv2.CHAIN_APPROX_SIMPLE)[1]

# 검출한 윤곽 그리기
# for pt in cnts:
#     x, y, w, h = cv2.boundingRect(pt)
#     # 너무 크거나 작은 부분 제거
#     if w < 30 or w > 200: continue
#     print(x, y, w, h)        # 결과 출력
#     cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
    

# 화면 오른쪽에 결과 출력
plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.savefig("find_contours.png", dpi=200)
plt.show()
